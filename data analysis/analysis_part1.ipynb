# %%
#data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('data/indian_cities.csv')

# %%
df
# Out:
#      Rank        City           State  Population  Metro_Population  Sexratio  \
# 0       1      Mumbai     Maharashtra    12442373          18414288       853
# 1       2       Delhi           Delhi    11034555          16314838       876
# 2       3   Bangalore       Karnataka     8443675           8499399       923
# 3       4   Hyderabad  Andhra Pradesh     6731790           7749334       955
# 4       5   Ahmedabad         Gujarat     5577940           6352254       898
# ..    ...         ...             ...         ...               ...       ...
# 493   494     Gangtok          Sikkim      100286            100286       912
# 494   495       Datia  Madhya Pradesh      100284            100284       900
# 495   496       Nagda  Madhya Pradesh      100039            100039       947
# 496   497    Banswara       Rajasthan       99969            101177       960
# 497   498  Kapurthala          Punjab       98916             98916       839
#
#      Literacy
# 0       89.73
# ...

# %%
df2 = pd.read_excel('data/report.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6332\53688309.py in <module>
# ----> 1 df2 = pd.read_excel('data/report.xlsx')
#
# c:\Users\v7aan\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\v7aan\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
# ...

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6332\3882145664.py in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df.head()
# Out:
#    Rank       City           State  Population  Metro_Population  Sexratio  \
# 0     1     Mumbai     Maharashtra    12442373          18414288       853
# 1     2      Delhi           Delhi    11034555          16314838       876
# 2     3  Bangalore       Karnataka     8443675           8499399       923
# 3     4  Hyderabad  Andhra Pradesh     6731790           7749334       955
# 4     5  Ahmedabad         Gujarat     5577940           6352254       898
#
#    Literacy
# 0     89.73
# 1     87.59
# 2     88.71
# 3     83.26
# 4     88.29

# %%
df.head(n = 30)
# Out:
#     Rank                  City           State  Population  Metro_Population  \
# 0      1                Mumbai     Maharashtra    12442373          18414288
# 1      2                 Delhi           Delhi    11034555          16314838
# 2      3             Bangalore       Karnataka     8443675           8499399
# 3      4             Hyderabad  Andhra Pradesh     6731790           7749334
# 4      5             Ahmedabad         Gujarat     5577940           6352254
# 5      6               Chennai      Tamil Nadu     4646732           8696010
# 6      7               Kolkata     West Bengal     4496694          14112536
# 7      8                 Surat         Gujarat     4467797           4585367
# 8      9                  Pune     Maharashtra     3124458           5049968
# 9     10                Jaipur       Rajasthan     3046163           3046163
# 10    11               Lucknow   Uttar Pradesh     2817105           2901474
# ...

# %%
df.tail()
# Out:
#      Rank        City           State  Population  Metro_Population  Sexratio  \
# 493   494     Gangtok          Sikkim      100286            100286       912
# 494   495       Datia  Madhya Pradesh      100284            100284       900
# 495   496       Nagda  Madhya Pradesh      100039            100039       947
# 496   497    Banswara       Rajasthan       99969            101177       960
# 497   498  Kapurthala          Punjab       98916             98916       839
#
#      Literacy
# 493     89.33
# 494     80.56
# 495     80.71
# 496     85.72
# 497     85.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              498 non-null    int64
#  1   City              498 non-null    object
#  2   State             498 non-null    object
#  3   Population        498 non-null    int64
#  4   Metro_Population  498 non-null    int64
#  5   Sexratio          498 non-null    int64
#  6   Literacy          498 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 27.4+ KB

# %%
df2.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6332\4286376316.py in <module>
# ----> 1 df2.info()
#
# NameError: name 'df2' is not defined

# %%
df2.describe()

# %%
df.describe(exclude = np.number)
# Out:
#               City          State
# count          498            498
# unique         497             30
# top     Aurangabad  Uttar Pradesh
# freq             2             64

# %%
df.describe(include ='all')
# Out:
#               Rank        City          State    Population  Metro_Population  \
# count   498.000000         498            498  4.980000e+02      4.980000e+02
# unique         NaN         497             30           NaN               NaN
# top            NaN  Aurangabad  Uttar Pradesh           NaN               NaN
# freq           NaN           2             64           NaN               NaN
# mean    249.500000         NaN            NaN  4.498030e+05      5.556033e+05
# std     143.904482         NaN            NaN  1.029319e+06      1.501008e+06
# min       1.000000         NaN            NaN  9.891600e+04      9.891600e+04
# 25%     125.250000         NaN            NaN  1.256420e+05      1.384625e+05
# 50%     249.500000         NaN            NaN  1.841050e+05      2.048060e+05
# 75%     373.750000         NaN            NaN  3.495960e+05      4.103862e+05
# max     498.000000         NaN            NaN  1.244237e+07      1.841429e+07
#
#            Sexratio    Literacy
# ...

# %%
df.isnull()   #to show if any value is missing or not
# Out:
#       Rank   City  State  Population  Metro_Population  Sexratio  Literacy
# 0    False  False  False       False             False     False     False
# 1    False  False  False       False             False     False     False
# 2    False  False  False       False             False     False     False
# 3    False  False  False       False             False     False     False
# 4    False  False  False       False             False     False     False
# ..     ...    ...    ...         ...               ...       ...       ...
# 493  False  False  False       False             False     False     False
# 494  False  False  False       False             False     False     False
# 495  False  False  False       False             False     False     False
# 496  False  False  False       False             False     False     False
# 497  False  False  False       False             False     False     False
#
# [498 rows x 7 columns]

# %%
df2.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6332\3936327964.py in <module>
# ----> 1 df2.columns
#
# NameError: name 'df2' is not defined

# %%
df2['total']= df2['english'] + df2['maths'] + df2['Hindi'] + df2['Science']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6332\2678702297.py in <module>
# ----> 1 df2['total']= df2['english'] + df2['maths'] + df2['Hindi'] + df2['Science']
#
# NameError: name 'df2' is not defined

# %%
df2['total'].plot(kind = 'bar', figsize=(15,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6332\4121153926.py in <module>
# ----> 1 df2['total'].plot(kind = 'bar', figsize=(15,5))
#
# NameError: name 'df2' is not defined
